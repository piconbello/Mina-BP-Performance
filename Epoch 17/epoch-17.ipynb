# %%
# %matplotlib inline
# %load_ext blackcellmagic
# %load_ext autoreload
# %autoreload 2

# %%
import pickle
import seaborn as sns
import matplotlib.pyplot as plt

from scipy.stats import binom
import pandas as pd
import numpy as np

from minavrfpy import lib

# %% [markdown]
# ## single epoch

# %%
epoch = 17
bp_key = "B62qrQiw9JhUumq457sMxicgQ94Z1WD9JChzJu19kBE8Szb5T8tcUAC"

results = lib.get_epoch_df(epoch, block_producer_key=bp_key)

df = results['df']
stakes_df = results['stakes_df']

# %% [markdown]
# ## outcome per epoch

# %%
sns.set(rc={"figure.figsize": (8, 5)})


counts_df = (
    df.groupby("epoch")
    .outcome.value_counts()
    .to_frame()
    .rename(columns={"outcome": "outcome_count"})
    .reset_index()
)

ax = sns.barplot(x="epoch", y="outcome_count", data=counts_df, hue="outcome")
ax.set_title("All Slots")
for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ## outcome grouped by super_charged

# %%
df.groupby(["epoch", "super_charged"]).outcome.value_counts()
# Out:
# epoch  super_charged  outcome
# 17     False          WON                    20
#                       LOST                   13
#                       MISSED_NOT_PRODUCED     4
#                       MISSED_HEIGHT_DIFF      1
#                       MISSED_TOO_LATE         1
#        True           WON                    11
#                       LOST                   10
#                       MISSED_NOT_PRODUCED     5
#                       MISSED_TOO_LATE         1
# Name: outcome, dtype: int64

# %%
sns.set(rc={"figure.figsize": (8, 5)})


counts_df = (
    df[df.super_charged == True].groupby("epoch")
    .outcome.value_counts()
    .to_frame()
    .rename(columns={"outcome": "outcome_count"})
    .reset_index()
)

ax = sns.barplot(x="epoch", y="outcome_count", data=counts_df, hue="outcome")
ax.set_title("Supercharged Slots")
for container in ax.containers:
    ax.bar_label(container)

# %%
df[df.outcome == "MISSED_NOT_PRODUCED"]
# Out:
#     epoch  slot  global_slot  block  winner_exists  saw_my_producer  bp_won  \
# 0      17    48       121428  False          False            False   False
# 2      17   372       121752  False          False            False   False
# 3      17   380       121760  False          False            False   False
# 23     17  1892       123272  85290           True            False   False
# 38     17  3464       124844  86373           True            False   False
# 39     17  3753       125133  False          False            False   False
# 41     17  3821       125201  False          False            False   False
# 52     17  5259       126639  False          False            False   False
# 63     17  7010       128390  False          False            False   False
#
#    block_time                    received_time  \
# 0          []                              NaT
# 2          []                              NaT
# 3          []                              NaT
# 23         [] 2021-11-28 19:50:15.271000+00:00
# 38         [] 2021-12-02 02:15:20.769000+00:00
# 39         []                              NaT
# 41         []                              NaT
# 52         []                              NaT
# 63         []                              NaT
#
#                                             winner_pk  super_charged  \
# 0   B62qkBoe9qNqxTiXBe5euvRvZi8rCUq9TgHfM2BwmcED7A...          False
# 2   B62qqX8ZCJtADkmeKBz9Xxv8avWUUtkQyaCbsfp14VEGa8...           True
# 3   B62qpKh56CmoaXpMuL5ZNE4qgB5nAL4d1nBrunAdFmNfy1...           True
# 23  B62qiap2uo2Kt8RzoupS8jqCvAKiUZZmiXZUJM9gpmc1zq...          False
# 38  B62qn1TWG7HuT2tHNPd4bp6eHJCm1wKAsPSVQ93oUohHpM...           True
# 39  B62qnKL3FsuFybueAX1GUy74FCaRmxFXayNaP1MKTJZu3Q...           True
# 41  B62qopfSgwEn28YdwZHh4khMy3KEG9dy8Jfrv7cveUJw2s...          False
# 52  B62qkBMexQj12N8fYEeXMz23qVYpPtXwJYsnmRGsXJYcpr...          False
# 63  B62qk6oTzxvDPt48cJJBFrMNSxaeZKGej5Vu3tTFmaeeU8...           True
#
#     block_height_equal  too_late min_bt  min_bt_minutes              outcome  \
# 0                False      True 0 days             0.0  MISSED_NOT_PRODUCED
# 2                False      True 0 days             0.0  MISSED_NOT_PRODUCED
# 3                False      True 0 days             0.0  MISSED_NOT_PRODUCED
# 23               False      True 0 days             0.0  MISSED_NOT_PRODUCED
# 38               False      True 0 days             0.0  MISSED_NOT_PRODUCED
# 39               False      True 0 days             0.0  MISSED_NOT_PRODUCED
# 41               False      True 0 days             0.0  MISSED_NOT_PRODUCED
# 52               False      True 0 days             0.0  MISSED_NOT_PRODUCED
# 63               False      True 0 days             0.0  MISSED_NOT_PRODUCED
#
#     next_block_in
# 0             NaN
# 2             NaN
# 3             NaN
# 23            NaN
# 38            NaN
# 39            NaN
# 41            NaN
# 52            NaN
# 63            NaN

# %%
df[df.outcome == "MISSED_HEIGHT_DIFF"]
# Out:
#     epoch  slot  global_slot  block  winner_exists  saw_my_producer  bp_won  \
# 15     17  1234       122614  84845           True             True   False
#
#                   block_time                    received_time  \
# 15  [0 days 00:03:07.085000] 2021-11-27 10:45:34.514000+00:00
#
#                                             winner_pk  super_charged  \
# 15  B62qo8FPFHTQ2J5eaCK74yfsMRBFT5bnr2iPomWLv61iGp...          False
#
#     block_height_equal  too_late                 min_bt  min_bt_minutes  \
# 15               False      True 0 days 00:03:07.085000        3.116667
#
#                outcome  next_block_in
# 15  MISSED_HEIGHT_DIFF            NaN

# %%
df[df.outcome == "MISSED_TOO_LATE"]
# Out:
#     epoch  slot  global_slot  block  winner_exists  saw_my_producer  bp_won  \
# 4      17   421       121801  False          False             True   False
# 40     17  3800       125180  False          False             True   False
#
#                   block_time received_time  \
# 4   [0 days 00:03:46.348000]           NaT
# 40  [0 days 00:03:30.828000]           NaT
#
#                                             winner_pk  super_charged  \
# 4   B62qnKL3FsuFybueAX1GUy74FCaRmxFXayNaP1MKTJZu3Q...           True
# 40  B62qo8FPFHTQ2J5eaCK74yfsMRBFT5bnr2iPomWLv61iGp...          False
#
#     block_height_equal  too_late                 min_bt  min_bt_minutes  \
# 4                False      True 0 days 00:03:46.348000        3.766667
# 40               False      True 0 days 00:03:30.828000        3.500000
#
#             outcome  next_block_in
# 4   MISSED_TOO_LATE            NaN
# 40  MISSED_TOO_LATE            NaN

# %% [markdown]
# ## slot luck
# try to visualize "slot luck"

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

SLOTS_PER_EPOCH = 7140

def get_slot_win_perc(stake, total_currency):
    return (1 - ((1 / 4) ** (stake / total_currency)))


epoch_data = []

total_currency = results['epoch_data']['total_currency']
total_staking_balance = results['stakes_df'].balance.sum()

slot_win_pct = get_slot_win_perc(
    total_staking_balance, total_currency
)    
expected_blocks_value = slot_win_pct * SLOTS_PER_EPOCH 

won_blocks = df[(df.epoch == epoch) & (df.outcome == 'WON')].block.count()
slots_won = df[(df.epoch == epoch)].slot.nunique()

data = binom.rvs(n=SLOTS_PER_EPOCH, p=slot_win_pct, size=100000)

k = np.arange(int(expected_blocks_value - 50), int(expected_blocks_value) + 50, 1)

plt.figure(epoch)

sns.histplot(data, kde=True, bins=k, ax=ax)
ax.axvline(slots_won, 0, 1, color="r")
ax.set_title(f"epoch {epoch}")

epoch_data.append({
    'epoch': epoch,
    'expected_slots': expected_blocks_value,
    'expected_slots_binom': binom(SLOTS_PER_EPOCH, slot_win_pct).expect(),
    'slot_win_pct': slot_win_pct,
    'won_slots': slots_won,
    'won_blocks': won_blocks,
    'orphan_rate': 1 - (won_blocks/slots_won)
})

print(f"epoch {epoch} - expected {round(expected_blocks_value)} slots - got {slots_won}... ")


plt.show()
# Out:
# epoch 17 - expected 76 slots - got 66...

# %%
epoch_slots_df = pd.DataFrame(epoch_data)

epoch_slots_df["cdf"] = epoch_slots_df.apply(
    lambda row: binom.cdf(row["won_slots"], SLOTS_PER_EPOCH, row["slot_win_pct"]),
    axis=1,
)
epoch_slots_df
# Out:
#    epoch  expected_slots  expected_slots_binom  slot_win_pct  won_slots  \
# 0     17       76.215057             76.215057      0.010674         66
#
#    won_blocks  orphan_rate       cdf
# 0          31     0.530303  0.130418
